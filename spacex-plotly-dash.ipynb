# %%
import pandas as pd
import requests
from dash import Dash, dcc, html, Input, Output
import plotly.express as px

launch_url = "https://api.spacexdata.com/v4/launches"
pad_url = "https://api.spacexdata.com/v4/launchpads"

launches = pd.json_normalize(requests.get(launch_url).json())
pads = pd.json_normalize(requests.get(pad_url).json())

pads = pads[['id', 'name']].rename(columns={'name': 'launchpad_name'})
launches = launches[['name', 'date_utc', 'success', 'launchpad']]

df = pd.merge(launches, pads, left_on='launchpad', right_on='id')
df['date_utc'] = pd.to_datetime(df['date_utc'])
df['year_month'] = df['date_utc'].dt.to_period('M').astype(str)

app = Dash(__name__)
app.title = "SpaceX Launch Dashboard"

app.layout = html.Div([
    html.H2("SpaceX Launch Dashboard", style={'textAlign': 'center'}),
    
    html.Div([
        html.Label("Select Launchpad:"),
        dcc.Dropdown(
            options=[{"label": name, "value": name} for name in df['launchpad_name'].unique()],
            value=None,
            id='pad-dropdown',
            placeholder="All Launchpads",
            clearable=True
        ),
    ], style={'width': '48%', 'display': 'inline-block'}),

    html.Div([
        html.Label("Select Date Range:"),
        dcc.DatePickerRange(
            id='date-picker',
            min_date_allowed=df['date_utc'].min().date(),
            max_date_allowed=df['date_utc'].max().date(),
            start_date=df['date_utc'].min().date(),
            end_date=df['date_utc'].max().date()
        )
    ], style={'width': '48%', 'float': 'right', 'display': 'inline-block'}),

    html.Br(), html.Hr(),

    dcc.Graph(id='bar-chart'),
    dcc.Graph(id='pie-chart'),
    dcc.Graph(id='line-chart')
])

@app.callback(
    [Output('bar-chart', 'figure'),
     Output('pie-chart', 'figure'),
     Output('line-chart', 'figure')],
    [Input('pad-dropdown', 'value'),
     Input('date-picker', 'start_date'),
     Input('date-picker', 'end_date')]
)
def update_charts(selected_pad, start_date, end_date):
    filtered = df.copy()
    if selected_pad:
        filtered = filtered[filtered['launchpad_name'] == selected_pad]
    if start_date and end_date:
        filtered = filtered[
            (filtered['date_utc'] >= pd.to_datetime(start_date)) &
            (filtered['date_utc'] <= pd.to_datetime(end_date))
        ]

    bar_fig = px.bar(
        filtered.groupby('launchpad_name').size().reset_index(name='Launch Count'),
        x='launchpad_name', y='Launch Count', title="Launches per Launchpad"
    )

    pie_fig = px.pie(
        filtered, names='success', title="Success vs Failure"
    )

    line_fig = px.line(
        filtered.groupby('year_month').size().reset_index(name='Launches'),
        x='year_month', y='Launches', title="Launches Over Time"
    )

    return bar_fig, pie_fig, line_fig

if __name__ == "__main__":
    app.run(debug=True)
# Out:
# C:\Users\kash7\AppData\Local\Temp\ipykernel_5008\1830144414.py:19: UserWarning:
#
# Converting to PeriodArray/Index representation will drop timezone information.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\datetimelike.py:536, in DatetimeLikeArrayMixin._validate_comparison_value(
#     self=<DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2...0+00:00']
# Length: 205, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#     535 try:
# --> 536     self._check_compatible_with(other)
#         other = Timestamp('2006-03-24 00:00:00')
#         self = <DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2007-03-21 01:10:00+00:00',
#  '2008-08-03 03:34:00+00:00', '2008-09-28 23:15:00+00:00',
#  '2009-07-13 03:35:00+00:00', '2010-06-04 18:45:00+00:00',
#  '2010-12-08 15:43:00+00:00', '2012-05-22 07:44:00+00:00',
#  '2012-10-08 00:35:00+00:00', '2013-03-01 19:10:00+00:00',
#  ...
#  '2022-11-18 22:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-05 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 205, dtype: datetime64[ns, UTC]
#     537 except (TypeError, IncompatibleFrequency) as err:
#     538     # e.g. tzawareness mismatch
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\datetimes.py:540, in DatetimeArray._check_compatible_with(
#     self=<DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2...0+00:00']
# Length: 205, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#     539     return
# --> 540 self._assert_tzawareness_compat(other)
#         other = Timestamp('2006-03-24 00:00:00')
#         self = <DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2007-03-21 01:10:00+00:00',
#  '2008-08-03 03:34:00+00:00', '2008-09-28 23:15:00+00:00',
#  '2009-07-13 03:35:00+00:00', '2010-06-04 18:45:00+00:00',
#  '2010-12-08 15:43:00+00:00', '2012-05-22 07:44:00+00:00',
#  '2012-10-08 00:35:00+00:00', '2013-03-01 19:10:00+00:00',
#  ...
#  '2022-11-18 22:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-05 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 205, dtype: datetime64[ns, UTC]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\datetimes.py:786, in DatetimeArray._assert_tzawareness_compat(
#     self=<DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2...0+00:00']
# Length: 205, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#     785 elif other_tz is None:
# --> 786     raise TypeError(
#     787         "Cannot compare tz-naive and tz-aware datetime-like objects"
#     788     )
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects
#
# The above exception was the direct cause of the following exception:
#
# InvalidComparison                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\datetimelike.py:983, in DatetimeLikeArrayMixin._cmp_method(
#     self=<DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2...0+00:00']
# Length: 205, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00'),
#     op=<built-in function ge>
# )
#     982 try:
# --> 983     other = self._validate_comparison_value(other)
#         other = Timestamp('2006-03-24 00:00:00')
#         self = <DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2007-03-21 01:10:00+00:00',
#  '2008-08-03 03:34:00+00:00', '2008-09-28 23:15:00+00:00',
#  '2009-07-13 03:35:00+00:00', '2010-06-04 18:45:00+00:00',
#  '2010-12-08 15:43:00+00:00', '2012-05-22 07:44:00+00:00',
#  '2012-10-08 00:35:00+00:00', '2013-03-01 19:10:00+00:00',
#  ...
#  '2022-11-18 22:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-05 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 205, dtype: datetime64[ns, UTC]
#     984 except InvalidComparison:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\datetimelike.py:539, in DatetimeLikeArrayMixin._validate_comparison_value(
#     self=<DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2...0+00:00']
# Length: 205, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#     537     except (TypeError, IncompatibleFrequency) as err:
#     538         # e.g. tzawareness mismatch
# --> 539         raise InvalidComparison(other) from err
#         other = Timestamp('2006-03-24 00:00:00')
#     541 elif not is_list_like(other):
#
# InvalidComparison: 2006-03-24 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 72, in update_charts(
#     selected_pad=None,
#     start_date='2006-03-24',
#     end_date='2022-12-05'
# )
#      69     filtered = filtered[filtered['launchpad_name'] == selected_pad]
#      70 if start_date and end_date:
#      71     filtered = filtered[
# ---> 72         (filtered['date_utc'] >= pd.to_datetime(start_date)) &
#         filtered =                        name                  date_utc success  \
# 0                 FalconSat 2006-03-24 22:30:00+00:00   False
# 1                   DemoSat 2007-03-21 01:10:00+00:00   False
# 2               Trailblazer 2008-08-03 03:34:00+00:00   False
# 3                    RatSat 2008-09-28 23:15:00+00:00    True
# 4                  RazakSat 2009-07-13 03:35:00+00:00    True
# ..                      ...                       ...     ...
# 200           Transporter-6 2022-12-01 00:00:00+00:00    None
# 201                   TTL-1 2022-12-01 00:00:00+00:00    None
# 202  WorldView Legion 1 & 2 2022-12-01 00:00:00+00:00    None
# 203     Viasat-3 & Arcturus 2022-12-01 00:00:00+00:00    None
# 204          O3b mPower 3.4 2022-12-01 00:00:00+00:00    None
#
#                     launchpad                        id   launchpad_name  \
# 0    5e9e4502f5090995de566f86  5e9e4502f5090995de566f86  Kwajalein Atoll
# 1    5e9e4502f5090995de566f86  5e9e4502f5090995de566f86  Kwajalein Atoll
# 2    5e9e4502f5090995de566f86  5e9e4502f5090995de566f86  Kwajalein Atoll
# 3    5e9e4502f5090995de566f86  5e9e4502f5090995de566f86  Kwajalein Atoll
# 4    5e9e4502f5090995de566f86  5e9e4502f5090995de566f86  Kwajalein Atoll
# ..                        ...                       ...              ...
# 200  5e9e4501f509094ba4566f84  5e9e4501f509094ba4566f84     CCSFS SLC 40
# 201  5e9e4502f509092b78566f87  5e9e4502f509092b78566f87      VAFB SLC 4E
# 202  5e9e4501f509094ba4566f84  5e9e4501f509094ba4566f84     CCSFS SLC 40
# 203  5e9e4502f509094188566f88  5e9e4502f509094188566f88       KSC LC 39A
# 204  5e9e4501f509094ba4566f84  5e9e4501f509094ba4566f84     CCSFS SLC 40
#
#     year_month
# 0      2006-03
# 1      2007-03
# 2      2008-08
# 3      2008-09
# 4      2009-07
# ..         ...
# 200    2022-12
# 201    2022-12
# 202    2022-12
# 203    2022-12
# 204    2022-12
#
# [205 rows x 7 columns]
#         start_date = '2006-03-24'
#         pd = <module 'pandas' from 'C:\\Users\\kash7\\AppData\\Roaming\\Python\\Python312\\site-packages\\pandas\\__init__.py'>
#         end_date = '2022-12-05'
#      73         (filtered['date_utc'] <= pd.to_datetime(end_date))
#      74     ]
#      76 bar_fig = px.bar(
#      77     filtered.groupby('launchpad_name').size().reset_index(name='Launch Count'),
#      78     x='launchpad_name', y='Launch Count', title="Launches per Launchpad"
#      79 )
#      81 pie_fig = px.pie(
#      82     filtered, names='success', title="Success vs Failure"
#      83 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(
#     self=0     2006-03-24 22:30:00+00:00
# 1     2007-03-21...date_utc, Length: 205, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#         other = Timestamp('2006-03-24 00:00:00')
#         method = <function OpsMixin.__ge__ at 0x000001D296F5EE80>
#         self = 0     2006-03-24 22:30:00+00:00
# 1     2007-03-21 01:10:00+00:00
# 2     2008-08-03 03:34:00+00:00
# 3     2008-09-28 23:15:00+00:00
# 4     2009-07-13 03:35:00+00:00
#                  ...
# 200   2022-12-01 00:00:00+00:00
# 201   2022-12-01 00:00:00+00:00
# 202   2022-12-01 00:00:00+00:00
# 203   2022-12-01 00:00:00+00:00
# 204   2022-12-01 00:00:00+00:00
# Name: date_utc, Length: 205, dtype: datetime64[ns, UTC]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(
#     self=0     2006-03-24 22:30:00+00:00
# 1     2007-03-21...date_utc, Length: 205, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#         other = Timestamp('2006-03-24 00:00:00')
#         self = 0     2006-03-24 22:30:00+00:00
# 1     2007-03-21 01:10:00+00:00
# 2     2008-08-03 03:34:00+00:00
# 3     2008-09-28 23:15:00+00:00
# 4     2009-07-13 03:35:00+00:00
#                  ...
# 200   2022-12-01 00:00:00+00:00
# 201   2022-12-01 00:00:00+00:00
# 202   2022-12-01 00:00:00+00:00
# 203   2022-12-01 00:00:00+00:00
# 204   2022-12-01 00:00:00+00:00
# Name: date_utc, Length: 205, dtype: datetime64[ns, UTC]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\series.py:6119, in Series._cmp_method(
#     self=0     2006-03-24 22:30:00+00:00
# 1     2007-03-21...date_utc, Length: 205, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00'),
#     op=<built-in function ge>
# )
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#         lvalues = <DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2007-03-21 01:10:00+00:00',
#  '2008-08-03 03:34:00+00:00', '2008-09-28 23:15:00+00:00',
#  '2009-07-13 03:35:00+00:00', '2010-06-04 18:45:00+00:00',
#  '2010-12-08 15:43:00+00:00', '2012-05-22 07:44:00+00:00',
#  '2012-10-08 00:35:00+00:00', '2013-03-01 19:10:00+00:00',
#  ...
#  '2022-11-18 22:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-05 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 205, dtype: datetime64[ns, UTC]
#         rvalues = Timestamp('2006-03-24 00:00:00')
#         op = <built-in function ge>
#         ops = <module 'pandas.core.ops' from 'C:\\Users\\kash7\\AppData\\Roaming\\Python\\Python312\\site-packages\\pandas\\core\\ops\\__init__.py'>
#    6121 return self._construct_result(res_values, name=res_name)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\array_ops.py:330, in comparison_op(
#     left=<DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2...0+00:00']
# Length: 205, dtype: datetime64[ns, UTC],
#     right=Timestamp('2006-03-24 00:00:00'),
#     op=<built-in function ge>
# )
#     321         raise ValueError(
#     322             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     323         )
#     325 if should_extension_dispatch(lvalues, rvalues) or (
#     326     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     327     and lvalues.dtype != object
#     328 ):
#     329     # Call the method on lvalues
# --> 330     res_values = op(lvalues, rvalues)
#         lvalues = <DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2007-03-21 01:10:00+00:00',
#  '2008-08-03 03:34:00+00:00', '2008-09-28 23:15:00+00:00',
#  '2009-07-13 03:35:00+00:00', '2010-06-04 18:45:00+00:00',
#  '2010-12-08 15:43:00+00:00', '2012-05-22 07:44:00+00:00',
#  '2012-10-08 00:35:00+00:00', '2013-03-01 19:10:00+00:00',
#  ...
#  '2022-11-18 22:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-05 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 205, dtype: datetime64[ns, UTC]
#         rvalues = Timestamp('2006-03-24 00:00:00')
#         op = <built-in function ge>
#     332 elif is_scalar(rvalues) and isna(rvalues):  # TODO: but not pd.NA?
#     333     # numpy does not like comparisons vs None
#     334     if op is operator.ne:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(
#     self=<DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2...0+00:00']
# Length: 205, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#         other = Timestamp('2006-03-24 00:00:00')
#         method = <function OpsMixin.__ge__ at 0x000001D296F5EE80>
#         self = <DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2007-03-21 01:10:00+00:00',
#  '2008-08-03 03:34:00+00:00', '2008-09-28 23:15:00+00:00',
#  '2009-07-13 03:35:00+00:00', '2010-06-04 18:45:00+00:00',
#  '2010-12-08 15:43:00+00:00', '2012-05-22 07:44:00+00:00',
#  '2012-10-08 00:35:00+00:00', '2013-03-01 19:10:00+00:00',
#  ...
#  '2022-11-18 22:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-05 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 205, dtype: datetime64[ns, UTC]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(
#     self=<DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2...0+00:00']
# Length: 205, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#         other = Timestamp('2006-03-24 00:00:00')
#         self = <DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2007-03-21 01:10:00+00:00',
#  '2008-08-03 03:34:00+00:00', '2008-09-28 23:15:00+00:00',
#  '2009-07-13 03:35:00+00:00', '2010-06-04 18:45:00+00:00',
#  '2010-12-08 15:43:00+00:00', '2012-05-22 07:44:00+00:00',
#  '2012-10-08 00:35:00+00:00', '2013-03-01 19:10:00+00:00',
#  ...
#  '2022-11-18 22:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-05 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 205, dtype: datetime64[ns, UTC]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\datetimelike.py:985, in DatetimeLikeArrayMixin._cmp_method(
#     self=<DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2...0+00:00']
# Length: 205, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00'),
#     op=<built-in function ge>
# )
#     983     other = self._validate_comparison_value(other)
#     984 except InvalidComparison:
# --> 985     return invalid_comparison(self, other, op)
#         other = Timestamp('2006-03-24 00:00:00')
#         self = <DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2007-03-21 01:10:00+00:00',
#  '2008-08-03 03:34:00+00:00', '2008-09-28 23:15:00+00:00',
#  '2009-07-13 03:35:00+00:00', '2010-06-04 18:45:00+00:00',
#  '2010-12-08 15:43:00+00:00', '2012-05-22 07:44:00+00:00',
#  '2012-10-08 00:35:00+00:00', '2013-03-01 19:10:00+00:00',
#  ...
#  '2022-11-18 22:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-05 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 205, dtype: datetime64[ns, UTC]
#         op = <built-in function ge>
#     987 dtype = getattr(other, "dtype", None)
#     988 if is_object_dtype(dtype):
#     989     # We have to use comp_method_OBJECT_ARRAY instead of numpy
#     990     #  comparison otherwise it would raise when comparing to None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\invalid.py:40, in invalid_comparison(
#     left=<DatetimeArray>
# ['2006-03-24 22:30:00+00:00', '2...0+00:00']
# Length: 205, dtype: datetime64[ns, UTC],
#     right=Timestamp('2006-03-24 00:00:00'),
#     op=<built-in function ge>
# )
#      38 else:
#      39     typ = type(right).__name__
# ---> 40     raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      41 return res_values
#
# TypeError: Invalid comparison between dtype=datetime64[ns, UTC] and Timestamp
#
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\datetimelike.py:536, in DatetimeLikeArrayMixin._validate_comparison_value(
#     self=<DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2...0+00:00']
# Length: 112, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#     535 try:
# --> 536     self._check_compatible_with(other)
#         other = Timestamp('2006-03-24 00:00:00')
#         self = <DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2010-12-08 15:43:00+00:00',
#  '2012-05-22 07:44:00+00:00', '2012-10-08 00:35:00+00:00',
#  '2013-03-01 19:10:00+00:00', '2013-12-03 22:41:00+00:00',
#  '2014-01-06 18:06:00+00:00', '2014-04-18 19:25:00+00:00',
#  '2014-07-14 15:15:00+00:00', '2014-08-05 08:00:00+00:00',
#  ...
#  '2022-11-03 03:24:00+00:00', '2022-11-08 00:00:00+00:00',
#  '2022-11-15 00:00:00+00:00', '2022-11-22 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 112, dtype: datetime64[ns, UTC]
#     537 except (TypeError, IncompatibleFrequency) as err:
#     538     # e.g. tzawareness mismatch
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\datetimes.py:540, in DatetimeArray._check_compatible_with(
#     self=<DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2...0+00:00']
# Length: 112, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#     539     return
# --> 540 self._assert_tzawareness_compat(other)
#         other = Timestamp('2006-03-24 00:00:00')
#         self = <DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2010-12-08 15:43:00+00:00',
#  '2012-05-22 07:44:00+00:00', '2012-10-08 00:35:00+00:00',
#  '2013-03-01 19:10:00+00:00', '2013-12-03 22:41:00+00:00',
#  '2014-01-06 18:06:00+00:00', '2014-04-18 19:25:00+00:00',
#  '2014-07-14 15:15:00+00:00', '2014-08-05 08:00:00+00:00',
#  ...
#  '2022-11-03 03:24:00+00:00', '2022-11-08 00:00:00+00:00',
#  '2022-11-15 00:00:00+00:00', '2022-11-22 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 112, dtype: datetime64[ns, UTC]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\datetimes.py:786, in DatetimeArray._assert_tzawareness_compat(
#     self=<DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2...0+00:00']
# Length: 112, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#     785 elif other_tz is None:
# --> 786     raise TypeError(
#     787         "Cannot compare tz-naive and tz-aware datetime-like objects"
#     788     )
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects
#
# The above exception was the direct cause of the following exception:
#
# InvalidComparison                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\datetimelike.py:983, in DatetimeLikeArrayMixin._cmp_method(
#     self=<DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2...0+00:00']
# Length: 112, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00'),
#     op=<built-in function ge>
# )
#     982 try:
# --> 983     other = self._validate_comparison_value(other)
#         other = Timestamp('2006-03-24 00:00:00')
#         self = <DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2010-12-08 15:43:00+00:00',
#  '2012-05-22 07:44:00+00:00', '2012-10-08 00:35:00+00:00',
#  '2013-03-01 19:10:00+00:00', '2013-12-03 22:41:00+00:00',
#  '2014-01-06 18:06:00+00:00', '2014-04-18 19:25:00+00:00',
#  '2014-07-14 15:15:00+00:00', '2014-08-05 08:00:00+00:00',
#  ...
#  '2022-11-03 03:24:00+00:00', '2022-11-08 00:00:00+00:00',
#  '2022-11-15 00:00:00+00:00', '2022-11-22 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 112, dtype: datetime64[ns, UTC]
#     984 except InvalidComparison:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\datetimelike.py:539, in DatetimeLikeArrayMixin._validate_comparison_value(
#     self=<DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2...0+00:00']
# Length: 112, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#     537     except (TypeError, IncompatibleFrequency) as err:
#     538         # e.g. tzawareness mismatch
# --> 539         raise InvalidComparison(other) from err
#         other = Timestamp('2006-03-24 00:00:00')
#     541 elif not is_list_like(other):
#
# InvalidComparison: 2006-03-24 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 72, in update_charts(
#     selected_pad='CCSFS SLC 40',
#     start_date='2006-03-24',
#     end_date='2022-12-05'
# )
#      69     filtered = filtered[filtered['launchpad_name'] == selected_pad]
#      70 if start_date and end_date:
#      71     filtered = filtered[
# ---> 72         (filtered['date_utc'] >= pd.to_datetime(start_date)) &
#         filtered =                        name                  date_utc success  \
# 5      Falcon 9 Test Flight 2010-06-04 18:45:00+00:00    True
# 6                    COTS 1 2010-12-08 15:43:00+00:00    True
# 7                    COTS 2 2012-05-22 07:44:00+00:00    True
# 8                     CRS-1 2012-10-08 00:35:00+00:00    True
# 9                     CRS-2 2013-03-01 19:10:00+00:00    True
# ..                      ...                       ...     ...
# 197          O3b mPower 1,2 2022-11-01 00:00:00+00:00    None
# 199         SES-18 & SES-19 2022-11-01 00:00:00+00:00    None
# 200           Transporter-6 2022-12-01 00:00:00+00:00    None
# 202  WorldView Legion 1 & 2 2022-12-01 00:00:00+00:00    None
# 204          O3b mPower 3.4 2022-12-01 00:00:00+00:00    None
#
#                     launchpad                        id launchpad_name  \
# 5    5e9e4501f509094ba4566f84  5e9e4501f509094ba4566f84   CCSFS SLC 40
# 6    5e9e4501f509094ba4566f84  5e9e4501f509094ba4566f84   CCSFS SLC 40
# 7    5e9e4501f509094ba4566f84  5e9e4501f509094ba4566f84   CCSFS SLC 40
# 8    5e9e4501f509094ba4566f84  5e9e4501f509094ba4566f84   CCSFS SLC 40
# 9    5e9e4501f509094ba4566f84  5e9e4501f509094ba4566f84   CCSFS SLC 40
# ..                        ...                       ...            ...
# 197  5e9e4501f509094ba4566f84  5e9e4501f509094ba4566f84   CCSFS SLC 40
# 199  5e9e4501f509094ba4566f84  5e9e4501f509094ba4566f84   CCSFS SLC 40
# 200  5e9e4501f509094ba4566f84  5e9e4501f509094ba4566f84   CCSFS SLC 40
# 202  5e9e4501f509094ba4566f84  5e9e4501f509094ba4566f84   CCSFS SLC 40
# 204  5e9e4501f509094ba4566f84  5e9e4501f509094ba4566f84   CCSFS SLC 40
#
#     year_month
# 5      2010-06
# 6      2010-12
# 7      2012-05
# 8      2012-10
# 9      2013-03
# ..         ...
# 197    2022-11
# 199    2022-11
# 200    2022-12
# 202    2022-12
# 204    2022-12
#
# [112 rows x 7 columns]
#         start_date = '2006-03-24'
#         pd = <module 'pandas' from 'C:\\Users\\kash7\\AppData\\Roaming\\Python\\Python312\\site-packages\\pandas\\__init__.py'>
#         end_date = '2022-12-05'
#      73         (filtered['date_utc'] <= pd.to_datetime(end_date))
#      74     ]
#      76 bar_fig = px.bar(
#      77     filtered.groupby('launchpad_name').size().reset_index(name='Launch Count'),
#      78     x='launchpad_name', y='Launch Count', title="Launches per Launchpad"
#      79 )
#      81 pie_fig = px.pie(
#      82     filtered, names='success', title="Success vs Failure"
#      83 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(
#     self=5     2010-06-04 18:45:00+00:00
# 6     2010-12-08...date_utc, Length: 112, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#         other = Timestamp('2006-03-24 00:00:00')
#         method = <function OpsMixin.__ge__ at 0x000001D296F5EE80>
#         self = 5     2010-06-04 18:45:00+00:00
# 6     2010-12-08 15:43:00+00:00
# 7     2012-05-22 07:44:00+00:00
# 8     2012-10-08 00:35:00+00:00
# 9     2013-03-01 19:10:00+00:00
#                  ...
# 197   2022-11-01 00:00:00+00:00
# 199   2022-11-01 00:00:00+00:00
# 200   2022-12-01 00:00:00+00:00
# 202   2022-12-01 00:00:00+00:00
# 204   2022-12-01 00:00:00+00:00
# Name: date_utc, Length: 112, dtype: datetime64[ns, UTC]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(
#     self=5     2010-06-04 18:45:00+00:00
# 6     2010-12-08...date_utc, Length: 112, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#         other = Timestamp('2006-03-24 00:00:00')
#         self = 5     2010-06-04 18:45:00+00:00
# 6     2010-12-08 15:43:00+00:00
# 7     2012-05-22 07:44:00+00:00
# 8     2012-10-08 00:35:00+00:00
# 9     2013-03-01 19:10:00+00:00
#                  ...
# 197   2022-11-01 00:00:00+00:00
# 199   2022-11-01 00:00:00+00:00
# 200   2022-12-01 00:00:00+00:00
# 202   2022-12-01 00:00:00+00:00
# 204   2022-12-01 00:00:00+00:00
# Name: date_utc, Length: 112, dtype: datetime64[ns, UTC]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\series.py:6119, in Series._cmp_method(
#     self=5     2010-06-04 18:45:00+00:00
# 6     2010-12-08...date_utc, Length: 112, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00'),
#     op=<built-in function ge>
# )
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#         lvalues = <DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2010-12-08 15:43:00+00:00',
#  '2012-05-22 07:44:00+00:00', '2012-10-08 00:35:00+00:00',
#  '2013-03-01 19:10:00+00:00', '2013-12-03 22:41:00+00:00',
#  '2014-01-06 18:06:00+00:00', '2014-04-18 19:25:00+00:00',
#  '2014-07-14 15:15:00+00:00', '2014-08-05 08:00:00+00:00',
#  ...
#  '2022-11-03 03:24:00+00:00', '2022-11-08 00:00:00+00:00',
#  '2022-11-15 00:00:00+00:00', '2022-11-22 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 112, dtype: datetime64[ns, UTC]
#         rvalues = Timestamp('2006-03-24 00:00:00')
#         op = <built-in function ge>
#         ops = <module 'pandas.core.ops' from 'C:\\Users\\kash7\\AppData\\Roaming\\Python\\Python312\\site-packages\\pandas\\core\\ops\\__init__.py'>
#    6121 return self._construct_result(res_values, name=res_name)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\array_ops.py:330, in comparison_op(
#     left=<DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2...0+00:00']
# Length: 112, dtype: datetime64[ns, UTC],
#     right=Timestamp('2006-03-24 00:00:00'),
#     op=<built-in function ge>
# )
#     321         raise ValueError(
#     322             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     323         )
#     325 if should_extension_dispatch(lvalues, rvalues) or (
#     326     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     327     and lvalues.dtype != object
#     328 ):
#     329     # Call the method on lvalues
# --> 330     res_values = op(lvalues, rvalues)
#         lvalues = <DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2010-12-08 15:43:00+00:00',
#  '2012-05-22 07:44:00+00:00', '2012-10-08 00:35:00+00:00',
#  '2013-03-01 19:10:00+00:00', '2013-12-03 22:41:00+00:00',
#  '2014-01-06 18:06:00+00:00', '2014-04-18 19:25:00+00:00',
#  '2014-07-14 15:15:00+00:00', '2014-08-05 08:00:00+00:00',
#  ...
#  '2022-11-03 03:24:00+00:00', '2022-11-08 00:00:00+00:00',
#  '2022-11-15 00:00:00+00:00', '2022-11-22 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 112, dtype: datetime64[ns, UTC]
#         rvalues = Timestamp('2006-03-24 00:00:00')
#         op = <built-in function ge>
#     332 elif is_scalar(rvalues) and isna(rvalues):  # TODO: but not pd.NA?
#     333     # numpy does not like comparisons vs None
#     334     if op is operator.ne:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(
#     self=<DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2...0+00:00']
# Length: 112, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#         other = Timestamp('2006-03-24 00:00:00')
#         method = <function OpsMixin.__ge__ at 0x000001D296F5EE80>
#         self = <DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2010-12-08 15:43:00+00:00',
#  '2012-05-22 07:44:00+00:00', '2012-10-08 00:35:00+00:00',
#  '2013-03-01 19:10:00+00:00', '2013-12-03 22:41:00+00:00',
#  '2014-01-06 18:06:00+00:00', '2014-04-18 19:25:00+00:00',
#  '2014-07-14 15:15:00+00:00', '2014-08-05 08:00:00+00:00',
#  ...
#  '2022-11-03 03:24:00+00:00', '2022-11-08 00:00:00+00:00',
#  '2022-11-15 00:00:00+00:00', '2022-11-22 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 112, dtype: datetime64[ns, UTC]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(
#     self=<DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2...0+00:00']
# Length: 112, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00')
# )
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#         other = Timestamp('2006-03-24 00:00:00')
#         self = <DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2010-12-08 15:43:00+00:00',
#  '2012-05-22 07:44:00+00:00', '2012-10-08 00:35:00+00:00',
#  '2013-03-01 19:10:00+00:00', '2013-12-03 22:41:00+00:00',
#  '2014-01-06 18:06:00+00:00', '2014-04-18 19:25:00+00:00',
#  '2014-07-14 15:15:00+00:00', '2014-08-05 08:00:00+00:00',
#  ...
#  '2022-11-03 03:24:00+00:00', '2022-11-08 00:00:00+00:00',
#  '2022-11-15 00:00:00+00:00', '2022-11-22 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 112, dtype: datetime64[ns, UTC]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\datetimelike.py:985, in DatetimeLikeArrayMixin._cmp_method(
#     self=<DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2...0+00:00']
# Length: 112, dtype: datetime64[ns, UTC],
#     other=Timestamp('2006-03-24 00:00:00'),
#     op=<built-in function ge>
# )
#     983     other = self._validate_comparison_value(other)
#     984 except InvalidComparison:
# --> 985     return invalid_comparison(self, other, op)
#         other = Timestamp('2006-03-24 00:00:00')
#         self = <DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2010-12-08 15:43:00+00:00',
#  '2012-05-22 07:44:00+00:00', '2012-10-08 00:35:00+00:00',
#  '2013-03-01 19:10:00+00:00', '2013-12-03 22:41:00+00:00',
#  '2014-01-06 18:06:00+00:00', '2014-04-18 19:25:00+00:00',
#  '2014-07-14 15:15:00+00:00', '2014-08-05 08:00:00+00:00',
#  ...
#  '2022-11-03 03:24:00+00:00', '2022-11-08 00:00:00+00:00',
#  '2022-11-15 00:00:00+00:00', '2022-11-22 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-11-01 00:00:00+00:00',
#  '2022-11-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00',
#  '2022-12-01 00:00:00+00:00', '2022-12-01 00:00:00+00:00']
# Length: 112, dtype: datetime64[ns, UTC]
#         op = <built-in function ge>
#     987 dtype = getattr(other, "dtype", None)
#     988 if is_object_dtype(dtype):
#     989     # We have to use comp_method_OBJECT_ARRAY instead of numpy
#     990     #  comparison otherwise it would raise when comparing to None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\invalid.py:40, in invalid_comparison(
#     left=<DatetimeArray>
# ['2010-06-04 18:45:00+00:00', '2...0+00:00']
# Length: 112, dtype: datetime64[ns, UTC],
#     right=Timestamp('2006-03-24 00:00:00'),
#     op=<built-in function ge>
# )
#      38 else:
#      39     typ = type(right).__name__
# ---> 40     raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      41 return res_values
#
# TypeError: Invalid comparison between dtype=datetime64[ns, UTC] and Timestamp
